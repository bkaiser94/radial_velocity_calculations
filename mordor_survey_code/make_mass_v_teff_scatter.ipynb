# %% [markdown]
# # Reconfiguring the notebook that was used to make the histogram to make a scatter plot

# %% [markdown]
# Copied and pasted from make_teff_stacked_hist.ipynb but I'm going to adapt it for the mass stacked histogram. I'm also going to just paste in the mass determination functions from cooling_model_analysis.py because those functions are so simple this may just be the best route
#
# This code also finds the masses that correspond to the Teff and logg values Simon gave back to me from the models. There appears to be like a <=0.01 disagreement in the central mass values, which seems good enough to me given the error bars.

# %% [markdown]
# Probably need to import the usual suspects of modules first to get things going.

# %%
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
from astropy.io import fits
from glob import glob
from astropy.time import Time
from astropy import coordinates as coord
from astropy import units as u
from astropy import constants as const
from astropy import convolution as conv
from astropy.table import Table, Column
#import scipy.interpolate as scinterp
import time

sys.path.append('../')
sys.path.append('/Users/BenKaiser/Desktop/radial_velocity_calculations/')

# %%
import spec_plot_tools as spt
import cal_params as cp
import cooling_model_tools as cmt

# %% [markdown]
# Need to read in the overall file for the data, and need that directory that it comes from.

# %%
input_path='/Users/BenKaiser/Desktop/MORDOR_Survey_paper/MORDOR_Survey_forPaper/Goodman_spectra_copy/'
output_path='/Users/BenKaiser/Desktop/'

# %%
#input_file='full_MORDOR_survey_1681141339_fullphotometry_fitparams.csv'
input_file='full_MORDOR_survey_1681141339_fullphotometry_fitparams_massadd.csv'

# %%
input_table= Table.read(input_path+input_file)

# %%
input_table.add_index('name')

# %%
input_table.pprint()
# Out:
#        name       ...
# ----------------- ...
# MORDOR J0008-2404 ...
#   SDSS J0049+2244 ...
# MORDOR J0110-5926 ...
# MORDOR J0110-5600 ...
# MORDOR J0126-4707 ...
#   SDSS J0132+1823 ...
# MORDOR J0135-6306 ...
#        LEHPM 1774 ...
#   LSPM J0211+0835 ...
# MORDOR J0225-3312 ...
#               ... ...
# MORDOR J2126-7502 ...
# MORDOR J2158+4243 ...
# MORDOR J2236-3635 ...
# MORDOR J2238-5558 ...
# MORDOR J2244+4204 ...
#   SDSS J2309+0959 ...
#   SDSS J2314+2717 ...
# MORDOR J2320-6637 ...
# MORDOR J2324-5942 ...
# MORDOR J2339+3728 ...
#      WD J2356-209 ...
# Length = 120 rows

# %%
for col in input_table.colnames:
    print(col)
# Out:
# name
# designation
# dr2_source_id
# gf19
# pwd
# f_pwd
# sp_type
# sed_sp_type
# dr3_source_id
# magnitude_difference
# solution_id
# DESIGNATION
# SOURCE_ID
# random_index
# ref_epoch
# ra
# ra_error
# dec
# dec_error
# parallax
# parallax_error
# parallax_over_error
# pm
# pmra
# pmra_error
# pmdec
# pmdec_error
# ra_dec_corr
# ra_parallax_corr
# ra_pmra_corr
# ra_pmdec_corr
# dec_parallax_corr
# dec_pmra_corr
# dec_pmdec_corr
# parallax_pmra_corr
# parallax_pmdec_corr
# pmra_pmdec_corr
# astrometric_n_obs_al
# astrometric_n_obs_ac
# astrometric_n_good_obs_al
# astrometric_n_bad_obs_al
# astrometric_gof_al
# astrometric_chi2_al
# astrometric_excess_noise
# astrometric_excess_noise_sig
# astrometric_params_solved
# astrometric_primary_flag
# nu_eff_used_in_astrometry
# pseudocolour
# pseudocolour_error
# ra_pseudocolour_corr
# dec_pseudocolour_corr
# parallax_pseudocolour_corr
# pmra_pseudocolour_corr
# pmdec_pseudocolour_corr
# astrometric_matched_transits
# visibility_periods_used
# astrometric_sigma5d_max
# matched_transits
# new_matched_transits
# matched_transits_removed
# ipd_gof_harmonic_amplitude
# ipd_gof_harmonic_phase
# ipd_frac_multi_peak
# ipd_frac_odd_win
# ruwe
# scan_direction_strength_k1
# scan_direction_strength_k2
# scan_direction_strength_k3
# scan_direction_strength_k4
# scan_direction_mean_k1
# scan_direction_mean_k2
# scan_direction_mean_k3
# scan_direction_mean_k4
# duplicated_source
# phot_g_n_obs
# phot_g_mean_flux
# phot_g_mean_flux_error
# phot_g_mean_flux_over_error
# phot_g_mean_mag
# phot_bp_n_obs
# phot_bp_mean_flux
# phot_bp_mean_flux_error
# phot_bp_mean_flux_over_error
# phot_bp_mean_mag
# phot_rp_n_obs
# phot_rp_mean_flux
# phot_rp_mean_flux_error
# phot_rp_mean_flux_over_error
# phot_rp_mean_mag
# phot_bp_rp_excess_factor
# phot_bp_n_contaminated_transits
# phot_bp_n_blended_transits
# phot_rp_n_contaminated_transits
# phot_rp_n_blended_transits
# phot_proc_mode
# bp_rp
# bp_g
# g_rp
# radial_velocity
# radial_velocity_error
# rv_method_used
# rv_nb_transits
# rv_nb_deblended_transits
# rv_visibility_periods_used
# rv_expected_sig_to_noise
# rv_renormalised_gof
# rv_chisq_pvalue
# rv_time_duration
# rv_amplitude_robust
# rv_template_teff
# rv_template_logg
# rv_template_fe_h
# rv_atm_param_origin
# vbroad
# vbroad_error
# vbroad_nb_transits
# grvs_mag
# grvs_mag_error
# grvs_mag_nb_transits
# rvs_spec_sig_to_noise
# phot_variable_flag
# l
# b
# ecl_lon
# ecl_lat
# in_qso_candidates
# in_galaxy_candidates
# non_single_star
# has_xp_continuous
# has_xp_sampled
# has_rvs
# has_epoch_photometry
# has_epoch_rv
# has_mcmc_gspphot
# has_mcmc_msc
# in_andromeda_survey
# classprob_dsc_combmod_quasar
# classprob_dsc_combmod_galaxy
# classprob_dsc_combmod_star
# teff_gspphot
# teff_gspphot_lower
# teff_gspphot_upper
# logg_gspphot
# logg_gspphot_lower
# logg_gspphot_upper
# mh_gspphot
# mh_gspphot_lower
# mh_gspphot_upper
# distance_gspphot
# distance_gspphot_lower
# distance_gspphot_upper
# azero_gspphot
# azero_gspphot_lower
# azero_gspphot_upper
# ag_gspphot
# ag_gspphot_lower
# ag_gspphot_upper
# ebpminrp_gspphot
# ebpminrp_gspphot_lower
# ebpminrp_gspphot_upper
# libname_gspphot
# clean_panstarrs1_oid
# ps1_original_ext_source_id
# ps1_angular_distance
# ps1_number_of_neighbours
# ps1_number_of_mates
# ps1_xm_flag
# ps1_obj_name
# ps1_obj_id
# ps1_ra
# ps1_dec
# ps1_ra_error
# ps1_dec_error
# ps1_epoch_mean
# ps1_g_mean_psf_mag
# ps1_g_mean_psf_mag_error
# ps1_g_flags
# ps1_r_mean_psf_mag
# ps1_r_mean_psf_mag_error
# ps1_r_flags
# ps1_i_mean_psf_mag
# ps1_i_mean_psf_mag_error
# ps1_i_flags
# ps1_z_mean_psf_mag
# ps1_z_mean_psf_mag_error
# ps1_z_flags
# ps1_y_mean_psf_mag
# ps1_y_mean_psf_mag_error
# ps1_y_flags
# ps1_n_detections
# ps1_zone_id
# ps1_obj_info_flag
# ps1_quality_flag
# tmass_original_ext_source_id
# tmass_angular_distance
# tmass_xm_flag
# tmass_clean_tmass_psc_xsc_oid
# tmass_number_of_neighbours
# tmass_number_of_mates
# tmass_ph_qual
# tmass_tmass_oid
# tmass_designation
# tmass_ra
# tmass_dec
# tmass_err_maj
# tmass_err_min
# tmass_err_ang
# tmass_j_mag
# tmass_j_mag_error
# tmass_h_mag
# tmass_h_mag_error
# tmass_ks_mag
# tmass_ks_mag_error
# tmass_ext_key
# tmass_j_date
# sdss_original_ext_source_id
# sdss_angular_distance
# sdss_gaia_astrometric_params
# sdss_sdssdr9_oid
# sdss_number_of_neighbours
# sdss_number_of_mates
# sdss_best_neighbour_multiplicity
# sdss_obj_id
# sdss_thing_id
# sdss_ra
# sdss_dec
# sdss_ra_error
# sdss_dec_error
# sdss_mjd
# sdss_u_mag
# sdss_u_mag_error
# sdss_g_mag
# sdss_g_mag_error
# sdss_r_mag
# sdss_r_mag_error
# sdss_i_mag
# sdss_i_mag_error
# sdss_z_mag
# sdss_z_mag_error
# sdss_objc_type
# sdss_clean_flag
# galex_objid
# galex_raj2000
# galex_dej2000
# galex_name
# galex_fuvmag
# galex_fuvmag_error
# galex_nuvmag
# galex_nuvmag_error
# galex_fafl
# galex_nafl
# galex_fexf
# galex_nexf
# vhs_srcid
# vhs_raj2000
# vhs_dej2000
# vhs_mclass
# vhs_pstar
# vhs_pgal
# vhs_pnoise
# vhs_ymjd
# vhs_yap3_mag
# vhs_yap3_mag_error
# vhs_jmjd
# vhs_jap3_mag
# vhs_jap3_mag_error
# vhs_hmjd
# vhs_hap3_mag
# vhs_hap3_mag_error
# vhs_ksmjd
# vhs_ksap3_mag
# vhs_ksap3_mag_error
# ukidss_ulas
# ukidss_m
# ukidss_raj2000
# ukidss_dej2000
# ukidss_ymag
# ukidss_ymag_error
# ukidss_jmag1
# ukidss_jmag1_error
# ukidss_jmag2
# ukidss_jmag2_error
# ukidss_hmag
# ukidss_hmag_error
# ukidss_kmag
# ukidss_kmag_error
# ukidss_mjd
# ukidss_pmra
# ukidss_pmde
# ukidss_cl
# teff
# teff_err
# logg
# logg_err
# m_wd
# m_wd_err
# h_or_he
# h/he
# h/he_err
# li/he
# li/he_err
# c/he
# c/he_err
# na/he
# na/he_err
# mg/he
# mg/he_err
# k/he
# k/he_err
# ca/he
# ca/he_err
# cr/he
# cr/he_err
# fe/he
# fe/he_err
# atm_type
# log_q
# note

# %%
bedard_thinH, thinH_interp_kind =cmt.get_cooling_model_table(cooling_modeler='bedard2020',atm_type='thinH')
bedard_thickH, thickH_interp_kind=cmt.get_cooling_model_table(cooling_modeler='bedard2020',atm_type='thickH')
# Out:
# *****
#
# bedard2020 with thinH atmosphere selected.
# Setting interp_kind='cubic'
# Because I know it works correctly-ish.

# %%
n=int(1e4)
def get_teff_logg_dists(row):
    return np.copy(np.random.normal(loc=row['teff'], scale=row['teff_err'], size=n)), np.copy(np.random.normal(loc=row['logg'], scale=row['logg_err'], size=n))

# %%
def get_mass(row, atm_type):
    if atm_type=='thinH':
        cooling_table=bedard_thinH
    elif atm_type=='thickH':
        cooling_table=bedard_thickH
    teff_dist, logg_dist=get_teff_logg_dists(row)
    mass_dist=cmt.operate_on_dist(teff_dist,logg_dist,cooling_table,cmt.loggteff_to_m)
    #print(mass_dist)
    #plt.hist(mass_dist)
    #plt.xlabel('mass')
    #plt.show()
    mean_mass=np.nanmean(mass_dist)
    std_mass=np.nanstd(mass_dist)
    return mean_mass, std_mass

# %%
def eval_mass(row):
    if row['sp_type']=='DQpec':
        mass, mass_err= get_mass(row,'thinH')
        row['m_wd']=mass
        row['m_wd_err']=mass_err
    elif row['sp_type']=='DC':
        if row['h_or_he']=='H':
            mass, mass_err= get_mass(row,'thickH')
        elif row['h_or_he']=='He':
            mass, mass_err= get_mass(row,'thinH')
        elif row['h_or_he']=='mix':
            mass, mass_err= get_mass(row,'thinH')
        else:
            pass
        row['m_wd']=mass
        row['m_wd_err']=mass_err
    else:
        pass

# %% [markdown]
# I no longer need this Jupyter notebook to calculate the masses for all of these objects, so I'm turning the next cells into Markdown cells. I also don't need it to export.

# %% [markdown]
# for row in input_table:
#     print('***************')
#     print(row['name'])
#     try:
#         eval_mass(row)
#     except ValueError as error:
#         print('ValueError:',error)
#         print('excepting the value error and proceeding')
# input_table['m_wd'].pprint()

# %% [markdown]
# output_file_parts=input_file.split('.')
# output_filename=output_file_parts[0]+'_massadd.csv'
# input_table.write(input_path+output_filename)

# %%
dc_array=input_table[np.where(input_table['sp_type']=='DC')]
dq_array=input_table[np.where(input_table['sp_type']=='DQpec')]
dz_array=input_table[np.where(input_table['sp_type']=='DZ')]

# %% [markdown]
# mean_dc_mass=np.nanmean(dc_array)
# std_dc_mass=np.std(dc_array)
#
# mean_all_mass=np.nanmean(input_table['m_wd'])
# std_all_mass=np.std(input_table['m_wd'])
#
# print('DC mass dist:',mean_dc_mass,'+/-' ,std_dc_mass)
# print('All mass dist:',mean_all_mass,'+/-',std_all_mass)

# %%
fig=spt.start_mnras_fig(width_cols=1)


#plt.hist([dc_array,dq_array,dz_array],bins=np.arange(0.2,1.0,0.1),stacked=True,color=[cp.sp_type_colors['DC'],cp.sp_type_colors['DQpec'],cp.sp_type_colors['DZ']],label=['DC','DQpec','DZ'])
#plt.scatter([dc_array,dq_array,dz_array],c=[cp.sp_type_colors['DC'],cp.sp_type_colors['DQpec'],cp.sp_type_colors['DZ']],label=['DC','DQpec','DZ'])
#plt.scatter(dc_array['teff'],dc_array['m_wd'],c=cp.sp_type_colors['DC'],label='DC')
#plt.scatter(dq_array['teff'],dq_array['m_wd'],c=cp.sp_type_colors['DQpec'],label='DQpec')
#plt.scatter(dz_array['teff'],dz_array['m_wd'],c=cp.sp_type_colors['DZ'],label='DZ')
plt.errorbar(dc_array['teff'],dc_array['m_wd'],xerr=dc_array['teff_err'],yerr=dc_array['m_wd_err'],c=cp.sp_type_colors['DC'],label='DC',linestyle='None',marker='o',markersize=cp.hrd_plot_marker_size)
plt.errorbar(dq_array['teff'],dq_array['m_wd'],c=cp.sp_type_colors['DQpec'],xerr=dq_array['teff_err'],yerr=dq_array['m_wd_err'],label='DQpec',linestyle='None',marker='o',markersize=cp.hrd_plot_marker_size)
plt.errorbar(dz_array['teff'],dz_array['m_wd'],c=cp.sp_type_colors['DZ'],xerr=dz_array['teff_err'],yerr=dz_array['m_wd_err'],label='DZ',linestyle='None',marker='o',markersize=cp.hrd_plot_marker_size)
plt.xlabel(r'$T_{\rm{eff}}$ (K)')
#plt.ylabel('Number')
plt.ylabel(r'$M_{\rm{WD}}$ $(M_{\odot})$')
#plt.xlim(0.2,1.0)
#plt.ylim(0,20)
plt.legend()
#plt.show()

start = time.time()
print(start)
time_string=str(start).split('.')[0]
plt.savefig(output_path+"mass_v_teff_scatter_"+time_string+'.pdf')#plt.grid(True)
# Out:
# 1752087518.9998562

# %%
test_mass=cmt.loggteff_to_m(4269.,7.034,bedard_thickH)
print(test_mass)

# %% [markdown]
# fig=spt.start_mnras_fig(width_cols=1)
# plt.hist([dc_array,dq_array,dz_array],bins=np.arange(3000,6000,500),stacked=True,color=[cp.sp_type_colors['DC'],cp.sp_type_colors['DQpec'],cp.sp_type_colors['DZ']],label=['DC','DQpec','DZ'])
# plt.xlabel(r'$T_{\rm{eff}}$ (K)')
# plt.ylabel('Number')
# plt.xlim(3000,5500)
# plt.ylim(0,25)
# plt.legend()
# plt.show()
#
# start = time.time()
# print(start)
# time_string=str(start).split('.')[0]
# #plt.savefig(output_path+"spec_type_hist_stacked_"+time_string+'.pdf')#plt.grid(True)

# %% [markdown]
# mean_teff= np.nanmean(input_table['teff'])
# std_teff=np.std(input_table['teff'])
# print(mean_teff,'+/-',std_teff)

# %% [markdown]
# ### I need to make sure these bars are the same colors as the scatter plot colors

# %% [markdown]
# On which point, I need to change the DZs to not be pink anymore. They look too much like the WD+dM points on many printers.
